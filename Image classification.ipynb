# %% [markdown]
# Every notebook starts with the following three lines; they ensure that any edits to libraries you make are reloaded here automatically, and also that any charts or images displayed are shown in this notebook.

# %%
# %reload_ext autoreload
# %autoreload 2
# %matplotlib inline

# %% [markdown]
# We import all the necessary packages. We are going to work with the fastai V1 library which sits on top of Pytorch 1.0. The fastai library provides many useful functions that enable us to quickly and easily build neural networks and train our models

# %%
from fastai.vision import *
from fastai.metrics import error_rate

# %%
# path = untar_data(URLs.PETS); path
path = Path('../Dataset/101_ObjectCategories')

# %%
path.ls()
path_img = path/'101_ObjectCategories'
# Out:
# [PosixPath('../Dataset/101_ObjectCategories/butterfly'),
#  PosixPath('../Dataset/101_ObjectCategories/menorah'),
#  PosixPath('../Dataset/101_ObjectCategories/sunflower'),
#  PosixPath('../Dataset/101_ObjectCategories/pizza'),
#  PosixPath('../Dataset/101_ObjectCategories/dragonfly'),
#  PosixPath('../Dataset/101_ObjectCategories/flamingo_head'),
#  PosixPath('../Dataset/101_ObjectCategories/dollar_bill'),
#  PosixPath('../Dataset/101_ObjectCategories/pigeon'),
#  PosixPath('../Dataset/101_ObjectCategories/wrench'),
#  PosixPath('../Dataset/101_ObjectCategories/joshua_tree'),
#  PosixPath('../Dataset/101_ObjectCategories/beaver'),
#  PosixPath('../Dataset/101_ObjectCategories/Leopards'),
#  PosixPath('../Dataset/101_ObjectCategories/buddha'),
#  PosixPath('../Dataset/101_ObjectCategories/euphonium'),
#  PosixPath('../Dataset/101_ObjectCategories/snoopy'),
#  PosixPath('../Dataset/101_ObjectCategories/garfield'),
#  PosixPath('../Dataset/101_ObjectCategories/cup'),
# ...

# %%
fname = get_image_files(path)
fname[:5]
# Out:
# []

# %%
np.random.seed(2)
pat = r'/([^/]+)'

# %%
data = ImageDataBunch.from_name_re(path, fname, pat, ds_tfms=get_transforms(), size=224,  bs=32
                                  ).normalize(imagenet_stats)
# Out:
# /home/prakashraj/fastai/fastai/data_block.py:454: UserWarning: Your training set is empty. If this is by design, pass `ignore_empty=True` to remove this warning.
#   warn("Your training set is empty. If this is by design, pass `ignore_empty=True` to remove this warning.")
# /home/prakashraj/fastai/fastai/data_block.py:457: UserWarning: Your validation set is empty. If this is by design, use `split_none()`
#                  or pass `ignore_empty=True` when labelling to remove this warning.
#   or pass `ignore_empty=True` when labelling to remove this warning.""")
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-127-951c8cb38922> in <module>
# ----> 1 data = ImageDataBunch.from_name_re(path, fname, pat, ds_tfms=get_transforms(), size=224,  bs=32
#       2                                   ).normalize(imagenet_stats)
#
# ...

# %%
data.show_batch(rows=3, figsize=(7,6))
